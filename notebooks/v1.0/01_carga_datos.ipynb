# %%
# Celda 1: Importar utilidades
import sys
import os
sys.path.insert(0, os.path.join(os.path.dirname(os.getcwd()), "src"))

from config import UE14, V4, COLORES_V4
from db_utils import load_convergencia_data, get_available_paises

# Celda 2: Cargar datos
df = load_convergencia_data(paises=UE14 + V4, años=list(range(2004, 2024)))
print(f"Datos cargados: {len(df)} registros")
print(f"Países: {sorted(df['pais'].unique())}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 6
#       3 import os
#       4 sys.path.insert(0, os.path.join(os.path.dirname(os.getcwd()), "src"))
# ----> 6 from config import UE14, V4, COLORES_V4
#       7 from db_utils import load_convergencia_data, get_available_paises
#       9 # Celda 2: Cargar datos
#
# ModuleNotFoundError: No module named 'config'
